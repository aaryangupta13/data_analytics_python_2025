# %%
# Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, date
from datasets import load_dataset

# Loading Data
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset["train"].to_pandas()

# Data Cleanup
df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])

# %%
job_data = {
    'job_id': [1, 2, 3, 4, 5],
    'job_title': ['Data Scientist', 'Software Engineer', 'Product Manager', 'Marketing Director', 'HR Manager'],
    'company_name': ['Google', 'Microsoft', 'Apple', 'Nike', 'Starbucks'],
    'job_location': ['Mountain View, CA', 'Redmond, WA', 'Cupertino, CA', 'Beaverton, OR', 'Seattle, WA']
}

company_data = {
    'company_name': ['Google', 'Microsoft', 'Apple', 'Nike', 'Starbucks'],
    'industry': ['Technology', 'Technology', 'Technology', 'Apparel', 'Food & Beverage'],
    'company_size': ['100,000+', '100,000+', '100,000+', '75,000+', '346,000+']
}

df_jobs = pd.DataFrame(job_data)
df_companies = pd.DataFrame(company_data)

# %%
df_jobs
# Out:
#    job_id           job_title company_name       job_location
# 0       1      Data Scientist       Google  Mountain View, CA
# 1       2   Software Engineer    Microsoft        Redmond, WA
# 2       3     Product Manager        Apple      Cupertino, CA
# 3       4  Marketing Director         Nike      Beaverton, OR
# 4       5          HR Manager    Starbucks        Seattle, WA

# %%
df_companies
# Out:
#   company_name         industry company_size
# 0       Google       Technology     100,000+
# 1    Microsoft       Technology     100,000+
# 2        Apple       Technology     100,000+
# 3         Nike          Apparel      75,000+
# 4    Starbucks  Food & Beverage     346,000+

# %%
df_US = df[df['job_country'] == 'United States'].copy()
df_US['job_posted_month'] = df['job_posted_date'].dt.strftime('%B')
df_US_pivot = df_US.pivot_table(index= 'job_posted_month', columns= 'job_title_short', aggfunc= 'size').reset_index()
df_US_pivot['job_posted_month_no'] = pd.to_datetime(df_US_pivot['job_posted_month'], format= '%B').dt.month
df_US_pivot.sort_values('job_posted_month_no', inplace= True)
df_US_pivot.set_index('job_posted_month', inplace= True)
df_US_pivot = df_US_pivot.drop(columns= 'job_posted_month_no')

df_US_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# January                    2655            6915                         60
# February                   3060            4956                         56
# March                      3183            4779                         59
# April                      2801            4867                         51
# May                        2976            4377                         49
# June                       2893            4645                         48
# July                       2570            4876                         65
# August                     3269            6318                         68
# September                  3224            4568                        113
# October                    3015            4882                        101
# November                   2793            4175                        132
# December                   2641            3472                        119
#
# job_title_short   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# January                          1544                   773
# February                         1258                   878
# March                            1114                   829
# April                            1025                   781
# May                               839                   746
# June                             1009                   812
# July                              883                   747
# August                           1186                   903
# September                         805                   775
# October                           871                   672
# November                          656                   684
# December                          601                   689
#
# job_title_short   Senior Data Scientist  Software Engineer
# job_posted_month
# January                            1552                114
# February                           1127                 90
# March                              1150                115
# April                               991                112
# May                                 914                 90
# June                               1033                 93
# July                               1095                153
# August                             1515                194
# September                          1014                228
# October                             987                219
# November                            816                194
# December                            752                212

# %%
df_US_software_pivot = pd.read_csv("https://lukeb.co/software_csv", index_col= 'job_posted_month')

df_US_software_pivot
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# March                             5814            4159
# April                             7232            4220
# May                               6718            4980
# June                              5902            4781
# July                              6839            4344
# August                            7413            4104
# September                         6139            4094
# October                           5026            4389
# November                          5653            4099
# December                          6731            4367

# %%
df_US_merged = df_US_pivot.merge(df_US_software_pivot, on= 'job_posted_month')

df_US_merged
# Out:
#                   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
#                   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# January                    2655            6915                         60
# February                   3060            4956                         56
# March                      3183            4779                         59
# April                      2801            4867                         51
# May                        2976            4377                         49
# June                       2893            4645                         48
# July                       2570            4876                         65
# August                     3269            6318                         68
# September                  3224            4568                        113
# October                    3015            4882                        101
# November                   2793            4175                        132
# December                   2641            3472                        119
#
#                   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# January                          1544                   773
# February                         1258                   878
# March                            1114                   829
# April                            1025                   781
# May                               839                   746
# June                             1009                   812
# July                              883                   747
# August                           1186                   903
# September                         805                   775
# October                           871                   672
# November                          656                   684
# December                          601                   689
#
#                   Senior Data Scientist  Software Engineer  \
# job_posted_month
# January                            1552                114
# February                           1127                 90
# March                              1150                115
# April                               991                112
# May                                 914                 90
# June                               1033                 93
# July                               1095                153
# August                             1515                194
# September                          1014                228
# October                             987                219
# November                            816                194
# December                            752                212
#
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# March                             5814            4159
# April                             7232            4220
# May                               6718            4980
# June                              5902            4781
# July                              6839            4344
# August                            7413            4104
# September                         6139            4094
# October                           5026            4389
# November                          5653            4099
# December                          6731            4367

# %%
top_5 = (df_US_merged
         .sum()
         .sort_values(ascending= False)
         .head()
         .index
         .to_list()
         )

df_US_merged[top_5]
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  Data Analyst  Data Scientist
# job_posted_month
# January                           5108          8494            6915
# February                          7298          6124            4956
# March                             5814          6218            4779
# April                             7232          6049            4867
# May                               6718          4993            4377
# June                              5902          5683            4645
# July                              6839          5201            4876
# August                            7413          6634            6318
# September                         6139          4639            4568
# October                           5026          5271            4882
# November                          5653          4531            4175
# December                          6731          3979            3472

# %%
df_US_merged[top_5].plot(kind= 'line', figsize= [8,5.2])
plt.title("Monthly Job Postings for the Top Tech Jobs in the US")
plt.xlabel("2023")
plt.ylabel("Job Count")
plt.ylim(0, 20000)
plt.legend(loc = 'upper right')

plt.tight_layout()
plt.show()
