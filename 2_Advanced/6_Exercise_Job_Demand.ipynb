# %% [markdown]
# # Exercise - Analyzing Data Science Job Demand

# %%
# Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, date
from datasets import load_dataset

# Loading Data
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset["train"].to_pandas()

# Data Cleanup
df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])

# %%
df_US = df[df['job_country'] == 'United States']

df_US
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
df_US['job_posted_monthly'] = df_US['job_posted_date'].dt.strftime('%B')

df_US
# Out:
# /var/folders/9n/s7pjshks0978pd3sp_7b8t0c0000gn/T/ipykernel_4382/2652673621.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_US['job_posted_monthly'] = df_US['job_posted_date'].dt.strftime('%B')
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# ...

# %%
top_titles = ["Data Analyst", "Data Engineer", "Data Scientist"]

# %%
df_US_pivot = df_US.pivot_table(index= 'job_posted_monthly', columns= 'job_title_short', aggfunc= 'size')[['Data Analyst', 'Data Engineer', 'Data Scientist']]

df_US_pivot
# Out:
# job_title_short     Data Analyst  Data Engineer  Data Scientist
# job_posted_monthly
# April                       6049           2801            4867
# August                      6634           3269            6318
# December                    3979           2641            3472
# February                    6124           3060            4956
# January                     8494           2655            6915
# July                        5201           2570            4876
# June                        5683           2893            4645
# March                       6218           3183            4779
# May                         4993           2976            4377
# November                    4531           2793            4175
# October                     5271           3015            4882
# September                   4639           3224            4568

# %%
df_US_pivot.reset_index(inplace= True)

df_US_pivot
# Out:
# job_title_short job_posted_monthly  Data Analyst  Data Engineer  \
# 0                            April          6049           2801
# 1                           August          6634           3269
# 2                         December          3979           2641
# 3                         February          6124           3060
# 4                          January          8494           2655
# 5                             July          5201           2570
# 6                             June          5683           2893
# 7                            March          6218           3183
# 8                              May          4993           2976
# 9                         November          4531           2793
# 10                         October          5271           3015
# 11                       September          4639           3224
#
# job_title_short  Data Scientist
# 0                          4867
# 1                          6318
# 2                          3472
# ...

# %%
df_US_pivot['month_no'] = pd.to_datetime(df_US_pivot["job_posted_monthly"], format= "%B").dt.month

df_US_pivot
# Out:
# job_title_short job_posted_monthly  Data Analyst  Data Engineer  \
# 0                            April          6049           2801
# 1                           August          6634           3269
# 2                         December          3979           2641
# 3                         February          6124           3060
# 4                          January          8494           2655
# 5                             July          5201           2570
# 6                             June          5683           2893
# 7                            March          6218           3183
# 8                              May          4993           2976
# 9                         November          4531           2793
# 10                         October          5271           3015
# 11                       September          4639           3224
#
# job_title_short  Data Scientist  month_no
# 0                          4867         4
# 1                          6318         8
# ...

# %%
df_US_pivot.sort_values('month_no', inplace= True)

df_US_pivot.set_index('job_posted_monthly', inplace= True)

df_US_pivot
# Out:
# job_title_short     Data Analyst  Data Engineer  Data Scientist  month_no
# job_posted_monthly
# January                     8494           2655            6915         1
# February                    6124           3060            4956         2
# March                       6218           3183            4779         3
# April                       6049           2801            4867         4
# May                         4993           2976            4377         5
# June                        5683           2893            4645         6
# July                        5201           2570            4876         7
# August                      6634           3269            6318         8
# September                   4639           3224            4568         9
# October                     5271           3015            4882        10
# November                    4531           2793            4175        11
# ...

# %%
df_US_pivot.drop(columns= 'month_no', inplace= True)

# %%
df_US_pivot.plot(kind= 'line',
                 xlabel= '2023', 
                 ylabel= 'Job Count',
                 title= 'Monthly Job Postings for Top Data Jobs in the US')

plt.show()
