# %%
# Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, date
from datasets import load_dataset

# Loading Data
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset["train"].to_pandas()

# Data Cleanup
df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])

# %%
df.loc[0:10, "salary_year_avg":"salary_hour_avg"]
# Out:
#     salary_year_avg  salary_hour_avg
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# 5               NaN              NaN
# 6               NaN              NaN
# 7               NaN              NaN
# 8               NaN              NaN
# 9               NaN              NaN
# 10              NaN              NaN

# %%
median_salary_year = df["salary_year_avg"].median()

median_salary_hour = df['salary_hour_avg'].median()

# %%
df_filled = df

df_filled['salary_year_avg'] = df_filled['salary_year_avg'].fillna(median_salary_year)
df_filled['salary_hour_avg'] = df_filled['salary_hour_avg'].fillna(median_salary_hour)

# %%
df_filled.loc[0:10, "salary_year_avg":"salary_hour_avg"]
# Out:
#     salary_year_avg  salary_hour_avg
# 0          115000.0            45.98
# 1          115000.0            45.98
# 2          115000.0            45.98
# 3          115000.0            45.98
# 4          115000.0            45.98
# 5          115000.0            45.98
# 6          115000.0            45.98
# 7          115000.0            45.98
# 8          115000.0            45.98
# 9          115000.0            45.98
# 10         115000.0            45.98

# %%
df_unique = df_filled

df_unique = df_unique.drop_duplicates(subset= ["job_title", "company_name"])

# %%
print("length of original df:           ", len(df_filled))
print("length of drop duplicates df:    ", len(df_unique))
print("Rows Dropped:                    ", len(df_filled)-len(df_unique))
# Out:
# length of original df:            785741
# length of drop duplicates df:     508042
# Rows Dropped:                     277699

# %%
df_filled[df_filled['job_title'].isin(["Data Analyst"]) & df_filled['company_name'].isin(["#EqualsTrue"])]
# Out:
#        job_title_short     job_title job_location              job_via  \
# 377558    Data Analyst  Data Analyst        Chile      via BeBee Chile
# 707054    Data Analyst  Data Analyst     Anywhere  via LinkedIn Panamá
#
#        job_schedule_type  job_work_from_home search_location  \
# 377558         Full-time               False           Chile
# 707054         Full-time                True          Panama
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 377558 2023-07-07 18:36:18                  False                 False
# 707054 2023-10-13 03:23:17                  False                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg company_name  \
# 377558       Chile        None         115000.0            45.98  #EqualsTrue
# 707054      Panama        None         115000.0            45.98  #EqualsTrue
#
#                                            job_skills  \
# ...

# %%
df_unique[df_unique['job_title'].isin(["Data Analyst"]) & df_unique['company_name'].isin(["#EqualsTrue"])]
# Out:
#        job_title_short     job_title job_location          job_via  \
# 377558    Data Analyst  Data Analyst        Chile  via BeBee Chile
#
#        job_schedule_type  job_work_from_home search_location  \
# 377558         Full-time               False           Chile
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 377558 2023-07-07 18:36:18                  False                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg company_name  \
# 377558       Chile        None         115000.0            45.98  #EqualsTrue
#
#                                            job_skills  \
# 377558  ['sql', 'python', 'r', 'tableau', 'power bi']
#
#                                           job_type_skills
# 377558  {'analyst_tools': ['tableau', 'power bi'], 'pr...

# %%
df_filled[df_filled['job_title'].isin(['Data Analyst'])].groupby(['company_name']).count().sort_values(by= "job_title", ascending= False)
# Out:
#                               job_title_short  job_title  job_location  \
# company_name
# Robert Half                               385        385           383
# Insight Global                            316        316           305
# Emprego                                   224        224           224
# Peroptyx                                  200        200           200
# Confidenziale                             139        139           139
# ...                                       ...        ...           ...
# โฮปฟูล จำกัด                                1          1             1
# ไอ แพสชั่น จำกัด                            1          1             1
# グローバルでサービスを展開する大手外資系ITサービス企業                1          1             1
# ランスタッド株式会社                                  1          1             1
# 1 Finance                                   1          1             1
#
#                               job_via  job_schedule_type  job_work_from_home  \
# company_name
# ...
